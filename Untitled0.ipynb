# %%
from google.colab import drive
from os.path import join

ROOT = '/content/drive/'
PROJ = 'My Drive/Telluride/metal/'

drive.mount(ROOT)

PROJECT_PATH = join(ROOT, PROJ)
# %cd "{PROJECT_PATH}"
# !git clone https://github.com/nmi-lab/torchneuromorphic.git
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/Telluride/metal
# Cloning into 'torchneuromorphic'...
# remote: Enumerating objects: 277, done.
# remote: Counting objects: 100% (277/277), done.
# remote: Compressing objects: 100% (186/186), done.
# remote: Total 277 (delta 171), reused 189 (delta 87), pack-reused 0
# Receiving objects: 100% (277/277), 79.50 KiB | 957.00 KiB/s, done.
# Resolving deltas: 100% (171/171), done.
